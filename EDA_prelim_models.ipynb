# %%
import pandas as pd
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
# %matplotlib inline 
sns.set(color_codes=True)

#read in data
df = pd.read_csv("/Users/annahmoore/Desktop/Insight/baseline_ADNI_CSF_prs_protein_cohort.csv")
df.head()
# Out:
#    RID  ID Visit_Code RBM.Sample.ID Sample_Received_Date  \
# 0    3   1         bl   KA8000CL-02            13-Sep-05
# 1    8   7         bl   GA8000D4-02            20-Sep-05
# 2   10   9         bl   AA80013M-03            11-Nov-05
# 3   19  13         bl   DA800199-03            30-Nov-05
# 4   29  19         bl   BA8000YF-03             1-Nov-05
#
#    Alpha.1.Microglobulin..A1Micro...ug.ml.  \
# 0                                  1.17609
# 1                                  0.97313
# 2                                  1.14613
# 3                                  0.96379
# 4                                  0.95904
#
#    Alpha.2.Macroglobulin..A2Macro...mg.mL.  \
# 0                                  0.07918
# 1                                  0.27875
# 2                                  0.07918
# 3                                  0.20412
# 4                                  0.04139
#
#    Alpha.1.Antichymotrypsin..AACT...ug.ml.  Alpha.1.Antitrypsin..AAT...mg.mL.  \
# ...

# %%
#exploratory data analysis with genetic risk score features
df.plot(x='superPGRSATN_kunkle', y='amylsqrt', kind='scatter')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
df.plot(x='CSF_AB42_SCORE_trans.CSF_AB42_SCORE_trans', y='amylsqrt', kind='scatter')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
#check for null values
df.iloc[:,5:150].isnull()
# Out:
#      Alpha.1.Microglobulin..A1Micro...ug.ml.  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# ..                                       ...
# 319                                    False
# 320                                    False
# 321                                    False
# 322                                    False
# 323                                    False
#
#      Alpha.2.Macroglobulin..A2Macro...mg.mL.  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# ..                                       ...
# 319                                    False
# 320                                    False
# ...

# %%
#list of missing values
missing_values=["."]
df = pd.read_csv("/Users/annahmoore/Desktop/Insight/baseline_ADNI_CSF_prs_protein_cohort.csv", na_values=missing_values)

# %%
#summarize missing values
print(df.isnull().sum())
print(df.isnull().values.any())

#total missing values in protein data
print(df.isnull().sum().sum())
#25
# Out:
# RID                                    0
# ID                                     0
# Visit_Code                             0
# RBM.Sample.ID                          0
# Sample_Received_Date                   0
#                                       ..
# CSF_AB42_noAPOE_SCORE_trans_reverse    0
# superPGRSATN                           0
# superPGRSATN_noAPOE                    0
# superPGRSATN_kunkle                    0
# superPGRSATN_kunkle_noAPOE             0
# Length: 233, dtype: int64
# True
# 25

# %%
#keep track of missing values that are dropped
print("Number of participants pre-amyloid NA drop")
number_of_rows=len(df)
print(number_of_rows)
# Out:
# Number of participants pre-drop
# 324

# %%
#drop missing values in the outcome
df_clean = df.dropna(subset=['amylsqrt'])
print("Number of participants post-amyloid NA drop")
number_of_rows=len(df_clean)
print(number_of_rows)
# Out:
# Number of participants post-amyloid NA drop
# 322

# %%
#drop missing values in the predictors
df_clean = df_clean.dropna(subset=['Alpha.1.Microglobulin..A1Micro...ug.ml.', 'Alpha.2.Macroglobulin..A2Macro...mg.mL.',
'Alpha.1.Antichymotrypsin..AACT...ug.ml.',
'Alpha.1.Antitrypsin..AAT...mg.mL.',
'Angiotensin.Converting.Enzyme..ACE...ng.ml.',
'Adiponectin..ug.mL.',
'Alpha.Fetoprotein..AFP...ng.mL.',
'Agouti.Related.Protein..AGRP...pg.mL.',
'Angiopoietin.2..ANG.2...ng.mL.',
'Angiotensinogen..ng.mL.',
'Apolipoprotein.A.I..Apo.A.I...mg.mL.',
'Apolipoprotein.A.II..Apo.A.II...ng.ml.',
'Apolipoprotein.A.IV..Apo.A.IV...ug.ml.',
'Apolipoprotein.B..Apo.B...ug.ml.',
'Apolipoprotein.C.I..Apo.C.I...ng.ml.',
'Apolipoprotein.C.III..Apo.C.III...ug.mL.',
'Apolipoprotein.D..Apo.D...ug.ml.',
'Apolipoprotein.E..Apo.E...ug.ml.',
'Apolipoprotein.H..Apo.H...ug.mL.',
'AXL.Receptor.Tyrosine.Kinase..AXL...ng.mL.',
'Beta.2.Microglobulin..B2M...ug.mL.',
'Brain.Derived.Neurotrophic.Factor..BDNF...ng.mL.',
'B.Lymphocyte.Chemoattractant..BLC...pg.ml.',
'Bone.Morphogenetic.Protein.6..BMP.6...ng.mL.',
'Brain.Natriuretic.Peptide...BNP...pg.ml.',
'Betacellulin..BTC...pg.mL.',
'Complement.C3..C3...mg.mL.',
'Cancer.Antigen.19.9..CA.19.9...U.mL.',
'Calcitonin..pg.mL.',
'CD.40.antigen..CD40...ng.mL.',
'CD40.Ligand..CD40.L...ng.mL.',
'CD5..CD5L...ng.ml.',
'Carcinoembryonic.Antigen..CEA...ng.mL.',
'Chromogranin.A..CgA...ng.mL.',
'Creatine.Kinase.MB..CK.MB...ng.mL.',
'Clusterin..CLU...ug.ml.',
'Ciliary.Neurotrophic.Factor..CNTF...pg.mL.',
'Complement.Factor.H..ug.ml.',
'Cortisol..Cortisol...ng.ml.',
'C.peptide..ng.ml.',
'C.Reactive.Protein..CRP...ug.mL.',
'Cystatin.C..ng.ml.',
'Epidermal.Growth.Factor..EGF...pg.mL.',
'Epidermal.Growth.Factor.Receptor..EGFR...ng.mL.',
'Epithelial.Derived.Neutrophil.Activating..ng.mL.',
'Eotaxin.1..pg.mL.',
'Eotaxin.3..pg.mL.',
'E.Selectin..ng.mL.',
'Fatty.Acid.Binding.Protein..heart...FABP..ng.mL.',
'Factor.VII..ng.mL.',
'FASLG.Receptor..FAS...ng.mL.',
'Fas.Ligand..FasL...pg.mL.',
'Fetuin.A..ug.ml.',
'Fibroblast.Growth.Factor.4..FGF.4...pg.mL.',
'Fibrinogen..mg.mL.',
'Ferritin..FRTN...ng.mL.',
'Follicle.Stimulating.Hormone..FSH...mIU.mL.',
'Growth.Hormone..GH...ng.mL.',
'Growth.Regulated.alpha.protein..GRO.alph..pg.mL.',
'Glutathione.S.Transferase.alpha..GST.alp..ng.ml.',
'Haptoglobin..mg.mL.',
'Heparin.Binding.EGF.Like.Growth.Factor....pg.mL.',
'Chemokine.CC.4..HCC.4...ng.mL.',
'Hepatocyte.Growth.Factor..HGF...ng.mL.',
'T.Lymphocyte.Secreted.Protein.I.309..I.3..pg.mL.',
'Intercellular.Adhesion.Molecule.1..ICAM...ng.mL.',
'Immunoglobulin.A..IgA...mg.mL.',
'Immunoglobulin.E..IgE...ng.mL.',
'Insulin.like.Growth.Factor.Binding.Prote..ng.mL.',
'Immunoglobulin.M..IGM...mg.mL.',
'Interleukin.13..IL.13...pg.mL.',
'Interleukin.16..IL.16...pg.mL.',
'Interleukin.18..IL.18...pg.mL.',
'Interleukin.3..IL.3...ng.mL.',
'Interleukin.6.receptor..IL.6r...ng.mL.',
'Interleukin.8..IL.8...pg.mL.',
'Insulin..uIU.mL.',
'Interferon.gamma.Induced.Protein.10..IP...pg.ml.',
'Kidney.Injury.Molecule.1...KIM.1...ng.ml.',
'Leptin..ng.mL.',
'Luteinizing.Hormone...LH...mIU.mL.',
'Apolipoprotein.a...Lp.a....ug.mL.',
'Monocyte.Chemotactic.Protein.1..MCP.1...pg.mL.',
'Monocyte.Chemotactic.Protein.2..MCP.2...pg.ml.',
'Monocyte.Chemotactic.Protein.3..MCP.3...pg.mL.',
'Monocyte.Chemotactic.Protein.4..MCP.4...pg.ml.',
'Macrophage.Colony.Stimulating.Factor.1....ng.mL.',
'Macrophage.Derived.Chemokine..MDC...pg.mL.',
'Macrophage.Migration.Inhibitory.Factor....ng.mL.',
'Monokine.Induced.by.Gamma.Interferon..MI..pg.ml.',
'Macrophage.Inflammatory.Protein.1.alpha..pg.mL.',
'Macrophage.Inflammatory.Protein.1.beta....pg.mL.',
'Macrophage.Inflammatory.Protein.3.alpha..pg.ml.',
'Matrix.Metalloproteinase.1..MMP.1...ng.ml.',
'Matrix.Metalloproteinase.10..MMP.10...ng.ml.',
'Matrix.Metalloproteinase.2..MMP.2...ng.mL.',
'Matrix.Metalloproteinase.7..MMP.7...ng.ml.',
'Matrix.Metalloproteinase.9..MMP.9...ng.mL.',
'Matrix.Metalloproteinase.9..total..MMP.9..ng.ml.',
'Myeloid.Progenitor.Inhibitory.Factor.1....ng.mL.',
'Myeloperoxidase..MPO...ng.mL.',
'Myoglobin..ng.mL.',
'Neutrophil.Gelatinase.Associated.Lipocal..ng.ml.',
'Neuronal.Cell.Adhesion.Molecule..Nr.CAM...ng.mL.',
'Osteopontin..ng.ml.',
'Plasminogen.Activator.Inhibitor.1..PAI.1..ng.mL.',
'Prostatic.Acid.Phosphatase..PAP...ng.mL.',
'Pregnancy.Associated.Plasma.Protein.A..P..mIU.mL.',
'Pulmonary.and.Activation.Regulated.Chemo..ng.mL.',
'Platelet.Derived.Growth.Factor.BB..PDGF...pg.ml.',
'Placenta.Growth.Factor..PLGF...pg.ml.',
'Pancreatic.Polypeptide..PPP...pg.ml.',
'Prolactin..PRL...ng.ml.',
'Proinsulin..Intact..pM.',
'Proinsulin..Total..pM.',
'Peptide.YY..PYY...pg.mL.',
'Receptor.for.advanced.glycosylation.end..ng.mL.',
'T.Cell.Specific.Protein.RANTES..RANTES...ng.mL.',
'Resistin..ng.ml.',
'Serum.Amyloid.P.Component..SAP...ug.mL.',
'Stem.Cell.Factor..SCF...pg.mL.',
'Serum.Glutamic.Oxaloacetic.Transaminase..ug.mL.',
'Sex.Hormone.Binding.Globulin..SHBG...nmol.L.',
'Superoxide.Dismutase.1..Soluble..SOD.1...ng.mL.',
'Sortilin..ng.mL.',
'Thyroxine.Binding.Globulin..TBG...ug.mL.',
'Thymus.Expressed.Chemokine..TECK...ng.mL.',
'Testosterone..Total..ng.ml.',
'Trefoil.Factor.3..TFF3...ug.ml.',
'Tamm.Horsfall.Urinary.Glycoprotein..THP...ug.ml.',
'Thrombospondin.1..ng.mL.',
'Tissue.Inhibitor.of.Metalloproteinases.1..ng.mL.',
'Thrombomodulin..TM...ng.ml.',
'Tenascin.C..TN.C...ng.mL.',
'Tumor.Necrosis.Factor.alpha..TNF.alpha...pg.mL.',
'Tumor.Necrosis.Factor.Receptor.Like.2..T..ng.mL.',
'Thrombopoietin..ng.mL.',
'TNF.Related.Apoptosis.Inducing.Ligand.Re..ng.mL.',
'Serotransferrin..Transferrin...mg.dl.',
'Thyroid.Stimulating.Hormone...TSH...uIU.mL.',
'Transthyretin..TTR...mg.dl.',
'Vascular.Cell.Adhesion.Molecule.1..VCAM...ng.mL.',
'Vascular.Endothelial.Growth.Factor..VEGF..pg.mL.',
'Vitronectin..ug.ml.',
'Vitamin.K.Dependent.Protein.S..VKDPS...ug.ml.'])
number_of_rows=len(df_clean)
print("Number of participants post-protein NA drop")
print(number_of_rows)
# Out:
# Number of participants post-protein NA drop
# 322

# %%
#split into train and test dataframes
#define target variable
y = df_clean.amylsqrt
#set seed
import random
random.seed(385)

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df_clean, y, test_size=0.2, random_state=31)
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)

#keep these rows, and select protein columns for x 
X_train = X_train.iloc[:,5:151]
X_test = X_test.iloc[:,5:151]

print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
# Out:
# (257, 233) (257,)
# (65, 233) (65,)
# (257, 146) (257,)
# (65, 146) (65,)

# %%
#run regression 
import math 
from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression


lasso = Lasso()
lasso.fit(X_train, y_train)
train_score=lasso.score(X_train,y_train)
test_score=lasso.score(X_test,y_test)
coeff_used = np.sum(lasso.coef_!=0)
print("training score:", train_score)
print("test score: ", test_score)
print("number of features used: ", coeff_used)
lasso001 = Lasso(alpha=0.01, max_iter=10e5)
lasso001.fit(X_train,y_train)
train_score001=lasso001.score(X_train,y_train)
test_score001=lasso001.score(X_test,y_test)
coeff_used001 = np.sum(lasso001.coef_!=0)
print("training score for alpha=0.01:", train_score001)
print("test score for alpha =0.01: ", test_score001)
print("number of features used: for alpha =0.01:", coeff_used001)
lasso00001 = Lasso(alpha=0.0001, max_iter=10e5)
lasso00001.fit(X_train,y_train)
train_score00001=lasso00001.score(X_train,y_train)
test_score00001=lasso00001.score(X_test,y_test)
coeff_used00001 = np.sum(lasso00001.coef_!=0)
print("training score for alpha=0.0001:", train_score00001) 
print("test score for alpha =0.0001: ", test_score00001)
print("number of features used: for alpha =0.0001:", coeff_used00001)
lr = LinearRegression()
lr.fit(X_train,y_train)
lr_train_score=lr.score(X_train,y_train)
lr_test_score=lr.score(X_test,y_test)
print("LR training score:", lr_train_score)
print("LR test score: ", lr_test_score)
plt.subplot(1,2,1)
plt.plot(lasso.coef_,alpha=0.7,linestyle='none',marker='*',markersize=5,color='red',label=r'Lasso; $\alpha = 1$',zorder=7) # alpha here is for transparency
plt.plot(lasso001.coef_,alpha=0.5,linestyle='none',marker='d',markersize=6,color='blue',label=r'Lasso; $\alpha = 0.01$') # alpha here is for transparency

plt.xlabel('Coefficient Index',fontsize=16)
plt.ylabel('Coefficient Magnitude',fontsize=16)
plt.legend(fontsize=13,loc=4)
plt.subplot(1,2,2)
plt.plot(lasso.coef_,alpha=0.7,linestyle='none',marker='*',markersize=5,color='red',label=r'Lasso; $\alpha = 1$',zorder=7) # alpha here is for transparency
plt.plot(lasso001.coef_,alpha=0.5,linestyle='none',marker='d',markersize=6,color='blue',label=r'Lasso; $\alpha = 0.01$') # alpha here is for transparency
plt.plot(lasso00001.coef_,alpha=0.8,linestyle='none',marker='v',markersize=6,color='black',label=r'Lasso; $\alpha = 0.00001$') # alpha here is for transparency
plt.plot(lr.coef_,alpha=0.7,linestyle='none',marker='o',markersize=5,color='green',label='Linear Regression',zorder=2)
plt.xlabel('Coefficient Index',fontsize=16)
plt.ylabel('Coefficient Magnitude',fontsize=16)
plt.legend(fontsize=13,loc=4)
plt.tight_layout()
plt.show()
# Out:
# training score: 0.036729492683718834
# test score:  -0.05829270210820358
# number of features used:  3
# training score for alpha=0.01: 0.5443854427802519
# test score for alpha =0.01:  -0.07602060487059736
# number of features used: for alpha =0.01: 76
# training score for alpha=0.0001: 0.7131940927746576
# test score for alpha =0.0001:  -0.8333228573839293
# number of features used: for alpha =0.0001: 145
# LR training score: 0.7133143661986907
# LR test score:  -0.9007847778427254
